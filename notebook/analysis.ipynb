# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/src")

import constants
from drone import Drone
import data_load

# %%
list_lines = data_load.read_lines(constants.DATA_PATH+'busy_day.in')
configs = data_load.read_configs(list_lines, constants.CONFIG_START)

num_products, prod_weights = data_load.read_products(list_lines, constants.PROD_START)
wh_locations, wh_inventory, wh_row_end = data_load.read_warehouse_details(list_lines, constants.WH_START)
num_orders, order_locations, order_quantity = data_load.read_orders(list_lines, order_start=wh_row_end, num_products=num_products)

# %%
order_locations = np.array(order_locations)
order_quantity = np.array(order_quantity)
wh_locations = np.array(wh_locations)
wh_inventory = np.array(wh_inventory)

# %%
x = range(400)
y = range(400,600)
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(111)

ax1.scatter(wh_locations[:,0], wh_locations[:,1], s=50, c='b', marker="o", label='ware_house')
ax1.scatter(order_locations[:,0], order_locations[:,1], s=20, c='r', marker="x", label='orders')
plt.legend(loc='upper left')
plt.show()
